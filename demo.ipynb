# %%
import stix_notebook

# %% [markdown]
# ## Simplest Example
#
# The simplest thing you can generate is a single STIX object. Do this by specifying the object type name, capitalized and with spaces replaced by underscores. All statements must be terminated with a period.

# %%
# %%stix
# Domain_Name.
# Out:
#     <svg id='chart1' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart1')[0];
#             visualizer1 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 1});
#             visualizer1.vizStix({
#     "type": "domain-name",
#     "id": "domain-name--8ddea1d4-9349-4f8e-b148-d17b0d57d7b2",
#     "value": "phillips.biz",
#     "spec_version": "2.1"
# }, {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;domain-name&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;domain-name--8ddea1d4-9349-4f8e-b148-d17b0d57d7b2&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;value&quot;</span><span class="p">:</span> <span class="s2">&quot;phillips.biz&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span>
# <span class="p">}</span>
# </pre></div>

# %% [markdown]
# ## Relationships
#
# You can create relationships by giving the capitalized source object type, followed by the lowercase relationship type, followed by the target object type. If the relationship type has a space in it, replace it with a hyphen ("-").

# %%
# %%stix
# Malware indicates Indicator.
# Out:
#     <svg id='chart2' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart2')[0];
#             visualizer2 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 2});
#             visualizer2.vizStix([{
#     "type": "malware",
#     "spec_version": "2.1",
#     "id": "malware--294ed005-dc5f-4207-a28d-6c95c815bdc0",
#     "created": "2020-01-02T22:20:55.000Z",
#     "modified": "2020-05-09T19:20:05.000Z",
#     "name": "measure",
#     "description": "Style concern what lay million could.",
#     "is_family": false,
#     "aliases": [
#         "our",
#         "upon",
#         "present"
#     ]
# },
# {
#     "type": "indicator",
#     "spec_version": "2.1",
#     "id": "indicator--efeec22f-1939-4acd-9dbe-f079d3db8979",
#     "created": "2020-06-17T23:04:56.000Z",
#     "modified": "2020-08-15T17:09:49.000Z",
#     "pattern": "[ipv4-addr:value = '1.2.3.4']",
#     "pattern_type": "stix",
#     "pattern_version": "1.0",
#     "valid_from": "2020-04-15T00:59:58Z"
# },
# {
#     "type": "relationship",
#     "spec_version": "2.1",
#     "id": "relationship--7662a183-ed9b-4317-9fc5-82d8e2fac02b",
#     "created": "2020-07-18T19:44:13.000Z",
#     "modified": "2021-05-22T20:54:34.000Z",
#     "relationship_type": "indicates",
#     "source_ref": "malware--294ed005-dc5f-4207-a28d-6c95c815bdc0",
#     "target_ref": "indicator--efeec22f-1939-4acd-9dbe-f079d3db8979"
# }], {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">[{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;malware&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;malware--294ed005-dc5f-4207-a28d-6c95c815bdc0&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;created&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-01-02T22:20:55.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;modified&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-05-09T19:20:05.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;name&quot;</span><span class="p">:</span> <span class="s2">&quot;measure&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;description&quot;</span><span class="p">:</span> <span class="s2">&quot;Style concern what lay million could.&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;is_family&quot;</span><span class="p">:</span> <span class="kc">false</span><span class="p">,</span>
#     <span class="nt">&quot;aliases&quot;</span><span class="p">:</span> <span class="p">[</span>
#         <span class="s2">&quot;our&quot;</span><span class="p">,</span>
#         <span class="s2">&quot;upon&quot;</span><span class="p">,</span>
#         <span class="s2">&quot;present&quot;</span>
#     <span class="p">]</span>
# <span class="p">},</span>
# <span class="p">{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;indicator&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quo

# %% [markdown]
# ## Counts
#
# You can create multiple objects of the same type using a numeral before the object type name.

# %%
# %%stix
# 2 Domain_Name.
# Out:
#     <svg id='chart3' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart3')[0];
#             visualizer3 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 3});
#             visualizer3.vizStix([{
#     "type": "domain-name",
#     "id": "domain-name--4e4f2571-2587-4253-84a3-1491c48888c4",
#     "value": "willis.biz",
#     "spec_version": "2.1"
# },
# {
#     "type": "domain-name",
#     "id": "domain-name--fedc2b28-f069-4f4d-a56f-1f5b93333119",
#     "value": "williams.com",
#     "spec_version": "2.1"
# }], {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">[{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;domain-name&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;domain-name--4e4f2571-2587-4253-84a3-1491c48888c4&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;value&quot;</span><span class="p">:</span> <span class="s2">&quot;willis.biz&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span>
# <span class="p">},</span>
# <span class="p">{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;domain-name&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;domain-name--fedc2b28-f069-4f4d-a56f-1f5b93333119&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;value&quot;</span><span class="p">:</span> <span class="s2">&quot;williams.com&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span>
# <span class="p">}]</span>
# </pre></div>

# %% [markdown]
# To create multiple object types at once, you can use multiple statements, each terminated with a period.

# %%
# %%stix
# Campaign. 2 Indicator.
# Out:
#     <svg id='chart4' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart4')[0];
#             visualizer4 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 4});
#             visualizer4.vizStix([{
#     "type": "campaign",
#     "spec_version": "2.1",
#     "id": "campaign--5a2aa605-b901-4895-a714-26aecc0a9eef",
#     "created": "2020-09-02T19:41:16.000Z",
#     "modified": "2021-06-20T23:45:51.000Z",
#     "name": "worry",
#     "objective": "Television either most and decision white ahead however.",
#     "confidence": 61
# },
# {
#     "type": "indicator",
#     "spec_version": "2.1",
#     "id": "indicator--93cd8a2d-b6fd-4fb0-8b1a-6aaee1f05e93",
#     "created": "2020-02-14T22:49:03.000Z",
#     "modified": "2020-12-12T15:20:48.000Z",
#     "indicator_types": [
#         "compromised"
#     ],
#     "pattern": "[ipv4-addr:value = '1.2.3.4']",
#     "pattern_type": "stix",
#     "pattern_version": "2.1",
#     "valid_from": "2019-10-01T20:27:17Z",
#     "valid_until": "2020-06-26T21:59:20Z",
#     "kill_chain_phases": [
#         {
#             "kill_chain_name": "lockheed-martin-cyber-kill-chain",
#             "phase_name": "command and control"
#         },
#         {
#             "kill_chain_name": "lOodRvxb",
#             "phase_name": "XauNIhAQJlPlLeQeots"
#         },
#         {
#             "kill_chain_name": "lockheed-martin-cyber-kill-chain",
#             "phase_name": "actions on objective"
#         },
#         {
#             "kill_chain_name": "lockheed-martin-cyber-kill-chain",
#             "phase_name": "reconnaissance"
#         },
#         {
#             "kill_chain_name": "lockheed-martin-cyber-kill-chain",
#             "phase_name": "installation"
#         }
#     ]
# },
# {
#     "type": "indicator",
#     "spec_version": "2.1",
#     "id": "indicator--1c69cc61-83d2-4dbd-b25f-3e220b14af53",
#     "created": "2018-11-09T14:37:35.000Z",
#     "modified": "2019-11-07T05:34:33.000Z",
#     "pattern": "[ipv4-addr:value = '1.2.3.4']",
#     "pattern_type": "stix",
#     "pattern_version": "1.0",
#     "valid_from": "2021-02-21T01:47:54Z"
# }], {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">[{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;campaign&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;campaign--5a2aa605-b901-4895-a714-26aecc0a9eef&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;created&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-09-02T19:41:16.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;modified&quot;</span><span class="p">:</span> <span class="s2">&quot;2021-06-20T23:45:51.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;name&quot;</span><span class="p">:</span> <span class="s2">&quot;worry&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;objective&quot;</span><span class="p">:</span> <span class="s2">&quot;Television either most and decision white ahead however.&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;confidence&quot;</span><span class="p">:</span> <span class="mi">61</span>
# <span class="p">},</span>
# <span class="p">{</span>
#     <span class

# %% [markdown]
# You can also generate multiple objects by surrounding them in parentheses:

# %%
# %%stix
# (Campaign 2 Indicator).
# Out:
#     <svg id='chart5' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart5')[0];
#             visualizer5 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 5});
#             visualizer5.vizStix([{
#     "type": "campaign",
#     "spec_version": "2.1",
#     "id": "campaign--e8365760-81ed-427d-acf9-5d85f8149c79",
#     "created": "2020-03-11T18:09:52.000Z",
#     "modified": "2020-06-22T09:49:14.000Z",
#     "name": "answer",
#     "description": "Through trouble tend series hundred case.",
#     "last_seen": "2021-08-24T01:07:25Z"
# },
# {
#     "type": "indicator",
#     "spec_version": "2.1",
#     "id": "indicator--340a4a85-b734-43ce-96b5-5182244ce51a",
#     "created": "2020-12-08T18:02:53.000Z",
#     "modified": "2021-06-16T07:23:16.000Z",
#     "pattern": "[ipv4-addr:value = '1.2.3.4']",
#     "pattern_type": "stix",
#     "pattern_version": "2.1",
#     "valid_from": "2020-06-28T00:56:23Z"
# },
# {
#     "type": "indicator",
#     "spec_version": "2.1",
#     "id": "indicator--18dda98e-bb16-4a78-bc88-dabef4125e07",
#     "created": "2019-02-20T21:00:45.000Z",
#     "modified": "2019-12-21T23:24:33.000Z",
#     "name": "perhaps",
#     "indicator_types": [
#         "compromised",
#         "malicious-activity",
#         "anomalous-activity",
#         "malicious-activity"
#     ],
#     "pattern": "[ipv4-addr:value = '1.2.3.4']",
#     "pattern_type": "stix",
#     "pattern_version": "2.1",
#     "valid_from": "2020-01-21T09:21:53Z",
#     "valid_until": "2020-12-25T21:44:32Z",
#     "confidence": 93
# }], {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">[{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;campaign&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;campaign--e8365760-81ed-427d-acf9-5d85f8149c79&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;created&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-03-11T18:09:52.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;modified&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-06-22T09:49:14.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;name&quot;</span><span class="p">:</span> <span class="s2">&quot;answer&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;description&quot;</span><span class="p">:</span> <span class="s2">&quot;Through trouble tend series hundred case.&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;last_seen&quot;</span><span class="p">:</span> <span class="s2">&quot;2021-08-24T01:07:25Z&quot;</span>
# <span class="p">},</span>
# <span class="p">{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;indicator&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;indicator--340a4a85-b734-43ce-96b5-5182244ce51a&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;created&quot;</span><span class="p">:</span> <span c

# %% [markdown]
# ## Relationships With Counts
#
# You can create multiple relationships at once as well.

# %%
# %%stix
# Campaign targets (Identity Vulnerability).
# Out:
#     <svg id='chart7' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart7')[0];
#             visualizer7 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 7});
#             visualizer7.vizStix([{
#     "type": "campaign",
#     "spec_version": "2.1",
#     "id": "campaign--130c1e32-391a-4262-a107-9594472dfde6",
#     "created": "2020-03-28T22:09:20.000Z",
#     "modified": "2020-08-18T09:37:11.000Z",
#     "name": "friend"
# },
# {
#     "type": "identity",
#     "spec_version": "2.1",
#     "id": "identity--8c68bd0f-fec5-4d0e-b941-ea7c87157322",
#     "created": "2020-01-14T06:55:55.000Z",
#     "modified": "2020-10-31T12:30:40.000Z",
#     "name": "Francis, Garcia and Martinez",
#     "description": "Integrated exuding challenge",
#     "contact_information": "803 Dana Vista\nLake Traciefurt, NJ 31564"
# },
# {
#     "type": "vulnerability",
#     "spec_version": "2.1",
#     "id": "vulnerability--abfaee2d-64df-4e73-a898-9effa65ad8ca",
#     "created": "2019-05-31T08:25:05.000Z",
#     "modified": "2019-09-23T22:38:40.000Z",
#     "name": "consider"
# },
# {
#     "type": "relationship",
#     "spec_version": "2.1",
#     "id": "relationship--298932b2-d1f1-47d4-a0d6-898153f5fcba",
#     "created": "2020-05-10T23:08:48.000Z",
#     "modified": "2020-07-19T17:03:30.000Z",
#     "relationship_type": "targets",
#     "source_ref": "campaign--130c1e32-391a-4262-a107-9594472dfde6",
#     "target_ref": "identity--8c68bd0f-fec5-4d0e-b941-ea7c87157322",
#     "start_time": "2021-05-05T08:45:58Z"
# },
# {
#     "type": "relationship",
#     "spec_version": "2.1",
#     "id": "relationship--ec55030a-ebe9-441d-9031-a7ee82344ab7",
#     "created": "2021-01-13T11:39:20.000Z",
#     "modified": "2021-03-26T00:23:02.000Z",
#     "relationship_type": "targets",
#     "source_ref": "campaign--130c1e32-391a-4262-a107-9594472dfde6",
#     "target_ref": "vulnerability--abfaee2d-64df-4e73-a898-9effa65ad8ca",
#     "start_time": "2021-04-05T21:42:29Z"
# }], {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">[{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;campaign&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;campaign--130c1e32-391a-4262-a107-9594472dfde6&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;created&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-03-28T22:09:20.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;modified&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-08-18T09:37:11.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;name&quot;</span><span class="p">:</span> <span class="s2">&quot;friend&quot;</span>
# <span class="p">},</span>
# <span class="p">{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;identity&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;identity--8c68bd0f-fec5-4d0e-b941-ea7c87157322&quot;</span><span class="p">,</spa

# %% [markdown]
# ## Variables
#
# You can give names to specific instances of objects by using a colon after the name, which must be lowercase. This lets you refer to them in other relationships, so the same object can be referenced multiple times.

# %%
# %%stix
# sam: Threat_Actor.
# sam uses Attack_Pattern.
# sam attributed-to Identity.
# (sam 2 Threat_Actor) uses Malware.
# Out:
#     <svg id='chart8' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart8')[0];
#             visualizer8 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 8});
#             visualizer8.vizStix([{
#     "type": "threat-actor",
#     "spec_version": "2.1",
#     "id": "threat-actor--9e9da6a5-9c46-43c4-a055-aaf08bcc2df8",
#     "created": "2020-05-06T11:42:25.000Z",
#     "modified": "2020-07-02T15:30:42.000Z",
#     "name": "push",
#     "description": "As trip start.",
#     "first_seen": "2019-10-21T17:53:50Z",
#     "last_seen": "2020-02-03T06:40:55Z",
#     "resource_level": "club",
#     "primary_motivation": "coercion",
#     "x_viz_variable_name": "sam"
# },
# {
#     "type": "attack-pattern",
#     "spec_version": "2.1",
#     "id": "attack-pattern--dfb50e0d-b1d6-4bb4-b5ec-3385fde09bbb",
#     "created": "2020-09-22T05:40:44.000Z",
#     "modified": "2021-09-03T07:28:56.000Z",
#     "name": "home",
#     "description": "Whatever forget scene politics choice although rather.",
#     "aliases": [
#         "by",
#         "thousand",
#         "group"
#     ],
#     "confidence": 73
# },
# {
#     "type": "relationship",
#     "spec_version": "2.1",
#     "id": "relationship--9e8ad902-fcd6-4ea0-b6c6-f432f913ee93",
#     "created": "2021-01-11T21:15:13.000Z",
#     "modified": "2021-05-04T06:11:14.000Z",
#     "relationship_type": "uses",
#     "source_ref": "threat-actor--9e9da6a5-9c46-43c4-a055-aaf08bcc2df8",
#     "target_ref": "attack-pattern--dfb50e0d-b1d6-4bb4-b5ec-3385fde09bbb",
#     "start_time": "2021-05-10T13:48:51Z",
#     "confidence": 7
# },
# {
#     "type": "identity",
#     "spec_version": "2.1",
#     "id": "identity--26444ab7-e6cf-44b1-a8e0-ba015104418b",
#     "created": "2020-02-23T21:59:44.000Z",
#     "modified": "2020-12-20T11:40:58.000Z",
#     "name": "Smith-Coleman",
#     "confidence": 12
# },
# {
#     "type": "relationship",
#     "spec_version": "2.1",
#     "id": "relationship--1642e194-8942-4379-8240-15933ef7e26e",
#     "created": "2019-11-28T12:14:32.000Z",
#     "modified": "2020-05-25T12:40:04.000Z",
#     "relationship_type": "attributed-to",
#     "description": "Ok pull role. Thousand fund rock traditional government effort shoulder. Dog consumer not single most his artist onto.",
#     "source_ref": "threat-actor--9e9da6a5-9c46-43c4-a055-aaf08bcc2df8",
#     "target_ref": "identity--26444ab7-e6cf-44b1-a8e0-ba015104418b"
# },
# {
#     "type": "threat-actor",
#     "spec_version": "2.1",
#     "id": "threat-actor--93c620fe-a630-4677-89a2-1ae64bad3acb",
#     "created": "2020-02-09T09:15:28.000Z",
#     "modified": "2020-10-27T10:01:35.000Z",
#     "name": "pass",
#     "first_seen": "2021-09-08T14:44:30Z",
#     "sophistication": "intermediate",
#     "resource_level": "government",
#     "primary_motivation": "accidental",
#     "personal_motivations": [
#         "dominance",
#         "personal-gain",
#         "unpredictable",
#         "personal-gain",
#         "organizational-gain"
#     ]
# },
# {
#     "type": "threat-actor",
#     "spec_version": "2.1",
#     "id": "threat-actor--879568c7-e714-4630-a134-81cf12fafec0",
#     "created": "2018-12-29T07:53:28.000Z",
#     "modified": "2019-11-04T01:37:24.000Z",
#     "name": "year",
#     "threat_actor_types": [
#         "criminal"
#     ],
#     "aliases": [
#         "tell",
#         "Democrat",
#         "security"
#     ],
#     "first_seen": "2020-11-26T14:17:50Z",
#     "personal_motivations": [
#         "unpredictable",
#         "coercion",
#         "notoriety"
#     ]
# },
# {
#     "type": "malware",
#     "spec_version": "2.1",
#     "id": "malware--8801746c-b254-44c6-863c-0c7d9f812f5a",
#     "created": "2020-11-03T11:19:34.000Z",
#     "modified": "2020-11-16T19:16:04.000Z",
#     "name": "style",
#     "description": "Candidate evidence too age.",
#     "is_family": true,
#     "first_seen": "2021-01-08T06:48:28Z",
#     "last_seen": "2021-07-27T23:00:16Z",
#     "implementation_languages": [
#         "lua",
#         "scala",
#         "perl",
#         "bash"
#     ]
# },
# {
#     "type": "relationship",
#     "spec_version": "2.1",
#     "id": "relationship--46fb9228-09ce-4959-b458-d99b41dfd12c",
#     "created": "2020-09-26T18:08:49.000Z",
#     "modified": "2021-07-31T10:03:07.000Z",
#     "relationship_type": "uses",
#     "description": "Particularly walk reality. Huge finally offer card environmental baby. Share him behind that.",
#     "source_ref": "threat-actor--9e9da6a5-9c46-43c4-a055-aaf08bcc2df8",
#     "target_ref": "malware--8801746c-b254-44c6-863c-0c7d9f812f5a"
# },
# {
#     "type": "relationship",
#     "spec_version": "2.1",
#     "id": "relationship--441d701a-0e90-4c11-8aa0-3d9402ce72ce",
#     "created": "2020-03-29T00:23:56.000Z",
#     "modified": "2020-11-29T01:56:55.000Z",
#     "relationship_type": "uses",
#     "description": "Talk leg newspaper involve perhaps. Sure whole describe.",
#     "source_ref": "threat-actor--93c620fe-a630-4677-89a2-1ae64bad3acb",
#     "target_ref": "malware--8801746c-b254-44c6-863c-0c7d9f812f5a",
#     "confidence": 17
# },
# {
#     "type": "relationship",
#     "spec_version": "2.1",
#     "id": "relationship--bbc6a2cf-07cf-42b1-a9e9-c858c0908cf7",
#     "created": "2021-03-23T01:58:39.000Z",
#     "modified": "2021-07-01T20:52:55.000Z",
#     "relationship_type": "uses",
#     "source_ref": "threat-actor--879568c7-e714-4630-a134-81cf12fafec0",
#     "target_ref": "malware--8801746c-b254-44c6-863c-0c7d9f812f5a",
#     "start_time": "2020-04-30T22:24:36Z",
#     "stop_time": "2020-05-01T19:01:32Z"
# }], {"userLabels": {"threat-actor--9e9da6a5-9c46-43c4-a055-aaf08bcc2df8": "sam"}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color:

# %% [markdown]
# ## Specific Property Values
#
# You can set properties to specific values by inserting a block of properties after the object type or variable. This block is surrounded by curly braces, and contains a property name followed by a colon and then the value for that property. Multiple properties are separated by commas.
#
# For example, to specify the name and sectors of an Identity instead of randomly generating them:

# %%
# %%stix
# Identity {name: "Agent Smith", sectors: ["technology"]}.
# Out:
#     <svg id='chart11' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart11')[0];
#             visualizer11 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 11});
#             visualizer11.vizStix({
#     "type": "identity",
#     "spec_version": "2.1",
#     "id": "identity--53bb83f4-0fe4-49fe-ad75-b5d545262980",
#     "created": "2020-11-18T08:51:41.000Z",
#     "modified": "2021-07-24T11:44:02.000Z",
#     "name": "Agent Smith",
#     "identity_class": "individual",
#     "sectors": [
#         "technology"
#     ]
# }, {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;identity&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;identity--53bb83f4-0fe4-49fe-ad75-b5d545262980&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;created&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-11-18T08:51:41.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;modified&quot;</span><span class="p">:</span> <span class="s2">&quot;2021-07-24T11:44:02.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;name&quot;</span><span class="p">:</span> <span class="s2">&quot;Agent Smith&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;identity_class&quot;</span><span class="p">:</span> <span class="s2">&quot;individual&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;sectors&quot;</span><span class="p">:</span> <span class="p">[</span>
#         <span class="s2">&quot;technology&quot;</span>
#     <span class="p">]</span>
# <span class="p">}</span>
# </pre></div>

# %% [markdown]
# ## Special Relationships
#
# Some relationships constitute special cases that are handled slightly differently than other relationships.
#
# ### object_refs
# Objects that have an `object_refs` property, such as Report or Opinion, can populate this property using the "on" keyword.

# %%
# %%stix
# Report on 3 Indicator.
# Out:
#     <svg id='chart12' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart12')[0];
#             visualizer12 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 12});
#             visualizer12.vizStix([{
#     "type": "report",
#     "spec_version": "2.1",
#     "id": "report--7c54389d-96f9-407c-baa2-8a0615f4aebe",
#     "created": "2019-03-16T15:20:20.000Z",
#     "modified": "2019-09-14T07:12:50.000Z",
#     "name": "nor",
#     "published": "2021-05-22T05:50:44Z",
#     "object_refs": [
#         "indicator--06c9488e-8432-4e16-95a7-a5ebe69af5f5",
#         "indicator--6a7ab097-e70d-48d9-b79c-541cc3bbeb9b",
#         "indicator--4f2193f6-e4c1-4c4e-8c7d-9f12bc0b0356"
#     ],
#     "confidence": 74
# },
# {
#     "type": "indicator",
#     "spec_version": "2.1",
#     "id": "indicator--06c9488e-8432-4e16-95a7-a5ebe69af5f5",
#     "created": "2020-07-08T03:52:38.000Z",
#     "modified": "2020-10-11T03:50:49.000Z",
#     "name": "shake",
#     "pattern": "[ipv4-addr:value = '1.2.3.4']",
#     "pattern_type": "stix",
#     "pattern_version": "2.1",
#     "valid_from": "2020-01-08T08:24:16Z",
#     "confidence": 62
# },
# {
#     "type": "indicator",
#     "spec_version": "2.1",
#     "id": "indicator--6a7ab097-e70d-48d9-b79c-541cc3bbeb9b",
#     "created": "2019-03-10T09:58:18.000Z",
#     "modified": "2020-02-26T22:03:36.000Z",
#     "description": "Dark together level I.",
#     "indicator_types": [
#         "anomalous-activity"
#     ],
#     "pattern": "[ipv4-addr:value = '1.2.3.4']",
#     "pattern_type": "stix",
#     "pattern_version": "2.1",
#     "valid_from": "2020-08-04T20:57:11Z",
#     "confidence": 44
# },
# {
#     "type": "indicator",
#     "spec_version": "2.1",
#     "id": "indicator--4f2193f6-e4c1-4c4e-8c7d-9f12bc0b0356",
#     "created": "2019-10-07T22:03:38.000Z",
#     "modified": "2019-12-07T12:23:49.000Z",
#     "name": "machine",
#     "pattern": "[ipv4-addr:value = '1.2.3.4']",
#     "pattern_type": "stix",
#     "pattern_version": "2.1",
#     "valid_from": "2020-09-29T04:19:02Z",
#     "confidence": 19
# }], {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">[{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;report&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;report--7c54389d-96f9-407c-baa2-8a0615f4aebe&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;created&quot;</span><span class="p">:</span> <span class="s2">&quot;2019-03-16T15:20:20.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;modified&quot;</span><span class="p">:</span> <span class="s2">&quot;2019-09-14T07:12:50.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;name&quot;</span><span class="p">:</span> <span class="s2">&quot;nor&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;published&quot;</span><span class="p">:</span> <span class="s2">&quot;2021-05-22T05:50:44Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;object_refs&quot;</span><span class="p">:</span> <span class="p">[</span>
#         <span class="s2">&quot;indicator--06c9488e-8432-4e16-95a7-a5ebe69af5f5&quot;</span><span class="p">,</span>
#         <span class="s2">&quot;in

# %% [markdown]
# ### Sightings
#
# Similarly, create sightings of objects using Sighting as the source object type and "of" as the relationship keyword.

# %%
# %%stix
# Sighting of Indicator.
# Out:
#     <svg id='chart14' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart14')[0];
#             visualizer14 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 14});
#             visualizer14.vizStix([{
#     "type": "indicator",
#     "spec_version": "2.1",
#     "id": "indicator--ae847be3-91e5-40b0-918e-b0a21c9a6386",
#     "created": "2020-04-13T21:21:16.000Z",
#     "modified": "2021-01-29T04:32:33.000Z",
#     "pattern": "[ipv4-addr:value = '1.2.3.4']",
#     "pattern_type": "stix",
#     "pattern_version": "2.1",
#     "valid_from": "2021-05-12T10:19:55Z"
# },
# {
#     "type": "sighting",
#     "spec_version": "2.1",
#     "id": "sighting--590bf537-c884-4e7d-a400-95afe37d51b8",
#     "created": "2020-09-09T16:44:09.294037Z",
#     "modified": "2020-09-09T16:44:09.294037Z",
#     "sighting_of_ref": "indicator--ae847be3-91e5-40b0-918e-b0a21c9a6386"
# }], {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">[{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;indicator&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;indicator--ae847be3-91e5-40b0-918e-b0a21c9a6386&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;created&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-04-13T21:21:16.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;modified&quot;</span><span class="p">:</span> <span class="s2">&quot;2021-01-29T04:32:33.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;pattern&quot;</span><span class="p">:</span> <span class="s2">&quot;[ipv4-addr:value = &#39;1.2.3.4&#39;]&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;pattern_type&quot;</span><span class="p">:</span> <span class="s2">&quot;stix&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;pattern_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;valid_from&quot;</span><span class="p">:</span> <span class="s2">&quot;2021-05-12T10:19:55Z&quot;</span>
# <span class="p">},</span>
# <span class="p">{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;sighting&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;sighting--590bf537-c884-4e7d-a400-95afe37d51b8&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;created&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-09-09T16:44:09.294037Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;modified&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-09-09T16:44:09.294037Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;sighting_of_ref&quot;</span><span class="p">:</span> <span class="s2">&quot;indicator--ae847be3-91e5-40b0-918e-b0a21c9a6386&quot;</span>
# <span class="p">}]</span>
# </pre></div>

# %% [markdown]
# ### Embedded Relationships
#
# Embedded relationships can be set like any other property, using the curly brace syntax with multiple embedded relationships separated by commas.

# %%
# %%stix
# Sighting {created_by_ref: Identity, observed_data_refs: Observed_Data} of Malware.
# Out:
#     <svg id='chart15' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart15')[0];
#             visualizer15 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 15});
#             visualizer15.vizStix([{
#     "type": "identity",
#     "spec_version": "2.1",
#     "id": "identity--b6dc9c77-4c7a-4906-ab77-b6429d54d213",
#     "created": "2020-12-04T03:05:17.000Z",
#     "modified": "2021-03-03T05:45:10.000Z",
#     "name": "Donovan-Cruz"
# },
# {
#     "type": "observed-data",
#     "spec_version": "2.1",
#     "id": "observed-data--dba57759-0970-49cf-aa3a-e0e1f52f8100",
#     "created": "2019-11-12T14:37:37.000Z",
#     "modified": "2019-11-15T14:23:19.000Z",
#     "first_observed": "2019-01-17T20:38:32Z",
#     "last_observed": "2019-12-13T13:05:01Z",
#     "number_observed": 111465998,
#     "object_refs": [
#         "network-traffic--83ac3fcb-36d4-40a4-8f1b-eb09656b20c6"
#     ],
#     "confidence": 45
# },
# {
#     "type": "malware",
#     "spec_version": "2.1",
#     "id": "malware--414a932c-ac0a-4d01-9ee9-05bfeb848a10",
#     "created": "2020-08-03T12:33:55.000Z",
#     "modified": "2020-12-01T10:56:43.000Z",
#     "name": "law",
#     "is_family": true,
#     "aliases": [
#         "too",
#         "tend",
#         "throw"
#     ],
#     "implementation_languages": [
#         "python",
#         "swift",
#         "scala",
#         "objective-c",
#         "java"
#     ],
#     "capabilities": [
#         "persists-after-system-reboot",
#         "cleans-traces-of-infection",
#         "anti-disassembly",
#         "captures-system-state-data"
#     ],
#     "confidence": 67
# },
# {
#     "type": "sighting",
#     "spec_version": "2.1",
#     "id": "sighting--544f38d7-429c-493d-8780-4aba5003e586",
#     "created_by_ref": "identity--b6dc9c77-4c7a-4906-ab77-b6429d54d213",
#     "created": "2020-09-09T16:44:30.234604Z",
#     "modified": "2020-09-09T16:44:30.234604Z",
#     "sighting_of_ref": "malware--414a932c-ac0a-4d01-9ee9-05bfeb848a10",
#     "observed_data_refs": [
#         "observed-data--dba57759-0970-49cf-aa3a-e0e1f52f8100"
#     ]
# }], {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">[{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;identity&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;identity--b6dc9c77-4c7a-4906-ab77-b6429d54d213&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;created&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-12-04T03:05:17.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;modified&quot;</span><span class="p">:</span> <span class="s2">&quot;2021-03-03T05:45:10.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;name&quot;</span><span class="p">:</span> <span class="s2">&quot;Donovan-Cruz&quot;</span>
# <span class="p">},</span>
# <span class="p">{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;observed-data&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <s

# %% [markdown]
# ## Chaining
#
# Objects can also be used as both a source and a target of two different relationships, effectively "chaining" them together.

# %%
# %%stix
# Campaign uses Malware targets Identity.
# Out:
#     <svg id='chart16' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart16')[0];
#             visualizer16 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 16});
#             visualizer16.vizStix([{
#     "type": "campaign",
#     "spec_version": "2.1",
#     "id": "campaign--18a8dbe3-adb6-4b32-8de8-027f34f8b326",
#     "created": "2019-11-03T17:17:31.000Z",
#     "modified": "2020-06-20T11:12:41.000Z",
#     "name": "defense",
#     "last_seen": "2021-01-09T11:47:24Z"
# },
# {
#     "type": "malware",
#     "spec_version": "2.1",
#     "id": "malware--cf46f8e2-bfd6-4b73-92ed-44b213d228eb",
#     "created": "2020-03-06T14:14:37.000Z",
#     "modified": "2020-05-14T03:15:49.000Z",
#     "name": "ever",
#     "is_family": true,
#     "aliases": [
#         "common",
#         "start",
#         "scene"
#     ],
#     "kill_chain_phases": [
#         {
#             "kill_chain_name": "syRkfylsUGOD",
#             "phase_name": "YhcOZswtpdXFbKSXLd"
#         },
#         {
#             "kill_chain_name": "xAaePiHtOPzXJImLKD",
#             "phase_name": "nYHXmHdpuTBN"
#         },
#         {
#             "kill_chain_name": "JYPIW",
#             "phase_name": "UvGzkDwX"
#         },
#         {
#             "kill_chain_name": "lockheed-martin-cyber-kill-chain",
#             "phase_name": "weaponization"
#         },
#         {
#             "kill_chain_name": "lockheed-martin-cyber-kill-chain",
#             "phase_name": "reconnaissance"
#         }
#     ]
# },
# {
#     "type": "identity",
#     "spec_version": "2.1",
#     "id": "identity--0598f503-ee90-4df7-a38c-be0c6d2a6bd8",
#     "created": "2019-10-02T19:05:40.000Z",
#     "modified": "2020-04-02T13:33:47.000Z",
#     "name": "Smith, Miller and Rivers",
#     "description": "Ergonomic holistic migration",
#     "confidence": 19
# },
# {
#     "type": "relationship",
#     "spec_version": "2.1",
#     "id": "relationship--464cf2e3-5cec-4079-90b0-87f235041f4b",
#     "created": "2020-08-21T09:53:47.000Z",
#     "modified": "2021-06-12T05:12:13.000Z",
#     "relationship_type": "targets",
#     "source_ref": "malware--cf46f8e2-bfd6-4b73-92ed-44b213d228eb",
#     "target_ref": "identity--0598f503-ee90-4df7-a38c-be0c6d2a6bd8",
#     "start_time": "2019-12-26T16:07:44Z",
#     "confidence": 92
# },
# {
#     "type": "relationship",
#     "spec_version": "2.1",
#     "id": "relationship--149657ff-aacb-4453-8758-bfb0d7045d27",
#     "created": "2019-07-09T13:06:53.000Z",
#     "modified": "2019-09-14T03:12:19.000Z",
#     "relationship_type": "uses",
#     "source_ref": "campaign--18a8dbe3-adb6-4b32-8de8-027f34f8b326",
#     "target_ref": "malware--cf46f8e2-bfd6-4b73-92ed-44b213d228eb"
# }], {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">[{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;campaign&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;campaign--18a8dbe3-adb6-4b32-8de8-027f34f8b326&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;created&quot;</span><span class="p">:</span> <span class="s2">&quot;2019-11-03T17:17:31.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;modified&quot;</span><span class="p">:</span> <span class="s2">&quot;2020-06-

# %% [markdown]
# ## Custom Objects and Properties
#
# The generator is able to generate custom objects or custom properties on existing objects, but requires editing the `custom_registry.json` file located in this directory. This file is a mapping of object type names to a variety of options and a listing of the object's properties. By default we've added a custom property to the `User_Account` type and a custom object type called `Foobar`. You can view the specifications of all the predefined STIX 2.1 object types in `stix2generator/stix21_registry.json`. Here is what the default custom registry looks like:
#
# ```json
# {
#     "Foobar": {
#         "type": "object",
#         "import": "common-properties",
#         "required": ["id", "some-property", "type"],
#         "properties": {
#             "type": "x-foobar",
#             "id": {
#                 "type": "string",
#                 "semantics": "stix-id",
#                 "stix-type": "x-foobar"
#             },
#             "some-property": {
#                 "type": "string",
#                 "semantics": "word"
#             },
#             "another-property": {
#                 "type": "string",
#                 "semantics": "sentence"
#             }
#         }
#     },
#     "User_Account": {
#         "type": "object",
#         "required": ["id", "type", "all-props-group", "x_foo"],
#         "properties": {
#             "x_foo": {
#                 "type": "string"
#             }
#         }
#     }
# }
# ```
#
# Once we add a custom property to an existing object in the builder's registry, objects of that type will include that property.

# %%
# %%stix
# User_Account.
# Out:
#     <svg id='chart17' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart17')[0];
#             visualizer17 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 17});
#             visualizer17.vizStix({
#     "type": "user-account",
#     "id": "user-account--998d6f8f-a2b5-4d04-aaf1-7a23dfdfaecb",
#     "user_id": "vcruz",
#     "can_escalate_privs": true,
#     "account_created": "2019-11-22T22:55:53Z",
#     "spec_version": "2.1",
#     "x_foo": "aRlbqnoXip"
# }, {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;user-account&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;user-account--998d6f8f-a2b5-4d04-aaf1-7a23dfdfaecb&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;user_id&quot;</span><span class="p">:</span> <span class="s2">&quot;vcruz&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;can_escalate_privs&quot;</span><span class="p">:</span> <span class="kc">true</span><span class="p">,</span>
#     <span class="nt">&quot;account_created&quot;</span><span class="p">:</span> <span class="s2">&quot;2019-11-22T22:55:53Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;x_foo&quot;</span><span class="p">:</span> <span class="s2">&quot;aRlbqnoXip&quot;</span>
# <span class="p">}</span>
# </pre></div>

# %% [markdown]
# Once we've added a new object type to the builder's registry, we can generate objects of our custom type.

# %%
# %%stix
# Foobar.
# Out:
#     <svg id='chart18' style="border: 2px solid #ababab;width:800px;height:600px;"></svg>
#
#     <script type="text/javascript">
#         require(["nbextensions/stix2viz/stix2viz"], function(stix2viz) {
#             chart = $('#chart18')[0];
#             visualizer18 = new stix2viz.Viz(chart, {"width": 800, "height": 600,
#                 "iconDir": "/nbextensions/stix2viz/icons", "id": 18});
#             visualizer18.vizStix({
#     "type": "x-foobar",
#     "spec_version": "2.1",
#     "id": "x-foobar--f58d2183-909b-48e0-ae52-8d4e466b3b57",
#     "created": "2021-03-30T20:53:55.000Z",
#     "modified": "2021-04-25T01:56:58.000Z",
#     "some-property": "me"
# }, {"userLabels": {}});
#         });
#     </script>
#     <style type="text/css">.highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #00A000 } /* Generic.Inserted */
# .highlight .go { color: #888888 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #7D9029 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #999999; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #D2413A; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #A0A000 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #BB6622; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #BB6688; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #BB6688 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */</style><div class="highlight"><pre><span></span><span class="p">{</span>
#     <span class="nt">&quot;type&quot;</span><span class="p">:</span> <span class="s2">&quot;x-foobar&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;spec_version&quot;</span><span class="p">:</span> <span class="s2">&quot;2.1&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;id&quot;</span><span class="p">:</span> <span class="s2">&quot;x-foobar--f58d2183-909b-48e0-ae52-8d4e466b3b57&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;created&quot;</span><span class="p">:</span> <span class="s2">&quot;2021-03-30T20:53:55.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;modified&quot;</span><span class="p">:</span> <span class="s2">&quot;2021-04-25T01:56:58.000Z&quot;</span><span class="p">,</span>
#     <span class="nt">&quot;some-property&quot;</span><span class="p">:</span> <span class="s2">&quot;me&quot;</span>
# <span class="p">}</span>
# </pre></div>
